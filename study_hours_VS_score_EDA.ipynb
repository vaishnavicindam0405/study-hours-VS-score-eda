# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavicindam0405/study-hours-VS-score-eda/blob/main/study_hours_VS_score_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("students_scores.csv")

# %%
df.head()
# Out:
#    student_id  gender  hours_studied  score
# 0           1    Male              1     45
# 1           2  Female              2     50
# 2           3    Male              3     55
# 3           4  Female              4     60
# 4           5    Male              5     70

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   student_id     20 non-null     int64
#  1   gender         20 non-null     object
#  2   hours_studied  20 non-null     int64
#  3   score          20 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 772.0+ bytes

# %%
df.describe()
# Out:
#        student_id  hours_studied      score
# count    20.00000      20.000000  20.000000
# mean     10.50000       3.850000  61.100000
# std       5.91608       2.109502  13.859825
# min       1.00000       1.000000  40.000000
# 25%       5.75000       2.000000  50.000000
# 50%      10.50000       3.500000  58.500000
# 75%      15.25000       5.250000  71.250000
# max      20.00000       8.000000  88.000000

# %%
df.isnull().sum()
# Out:
# student_id       0
# gender           0
# hours_studied    0
# score            0
# dtype: int64

# %%
df["score"].mean()
# Out:
# np.float64(61.1)

# %%
df["hours_studied"].mean()
# Out:
# np.float64(3.85)

# %%
df[['hours_studied' , 'score']].corr()
# Out:
#                hours_studied     score
# hours_studied       1.000000  0.992423
# score               0.992423  1.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['hours_studied'], df['score'])
plt.xlabel("Hours studied")
plt.ylabel("Score")
plt.title("Hours studies VS Score")
plt.show()
